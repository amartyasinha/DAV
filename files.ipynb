# %%
# df, 3 col, temp, humidity, airflow

import pandas as pd
import numpy as np

mydic = {'temp': np.random.randint(-5,35, 20), 'humidity':np.random.randn(20), 'airflow': np.random.randn(20)}

mydf = pd.DataFrame(mydic)

# %%
mydf
# Out:
#     temp  humidity   airflow
# 0     18  0.029642  0.225703
# 1     26  1.129867  0.809745
# 2     22 -0.760061 -0.714874
# 3     17  0.296694  0.481320
# 4     11 -1.704641  1.491158
# 5     -2 -0.063177 -0.031677
# 6     15 -0.092994  1.993343
# 7     29 -0.605453 -0.615308
# 8      1  2.259345 -0.671665
# 9     20  0.464446  0.428431
# 10     9 -0.049376  1.012752
# 11     0 -1.484464  0.166171
# 12    25 -1.942674 -0.138158
# 13    14 -1.197476  0.450341
# 14    -2 -0.472258  1.317705
# 15    28 -1.762505 -0.042013
# 16    26  0.072300  0.218190
# 17    10  1.457068 -0.716845
# 18     4 -0.037753  1.360649
# 19     0 -0.816018  0.645802

# %%
mydf.to_csv('temp.csv')
